# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
print("Hello World")

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
name = int(input('Write a number'))
print("Square of",name, "is", name*name)

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
num = int(input("Give a number"))
if(num<0): 
    print ("Negetive")
elif (num>0): 
    print("Positive")
else: 
    print("Zero")

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
num1 = int(input("First Number : "))
num2 = int(input("Second Number : "))
num3 = int(input("Third Number : "))
if(num1>=num2 and num1>=num3): 
    print (num1 ,"is the largest")
elif (num2>=num1 and num2>=num3): 
    print(num2 ,"is the largest")
else: 
    print(num3 ,"is the largest")

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
numb = int(input("Write a number : "))
ans = 1
for i in range (numb,1, -1):
    ans = ans*i
print("Factorial of", numb, "is",ans)

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
print(type(1))
print(type("name"))
print(type(2.5))
print(type(True))

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
num1 = int(input("Give 1st number : "))
num2 = int(input("Give 2nd number : "))
num1 = num1+num2
num2 = num1-num2
num1 = num1-num2

print("After swapping : 1st number is",num1,"2nd number is",num2)

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
cels = float(input("Write a temperature in Celsius : "))
fehr = (cels*(9/5))+32
print("Temperature in Fahrenheit : ",fehr)

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
str1 = "Hello"
str2 = " World"
print(str1+str2)

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
var = False
if isinstance(var, bool):
    print(var, "is boolean")
elif isinstance(var, int):
    print(var, "is integer")
elif isinstance(var, float):
    print(var, "is float")
elif isinstance(var, str):
    print(var, "is string")

else:
    print(var,"is of another type")

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
num1 = int(input("Write a number : "))
print(num1+num1)
print(num1-num1)
print(num1*num1)
print(num1/num1)

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
num1=1
num2=2

print("num1==num2 :", num1==num2) 
print("num1!=num2 :", num1!=num2)    
print("num1>num2  :", num1>num2)      
print("num1<num2  :", num1<num2)        
print("num1>=num2 :", num1>=num2)    
print("num1<=num2 :", num1<=num2)

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
num1 = True
num2 = False

print("num1 and num2:", num1 and num2) 
print("num1 or num2:", num1 or num2)
print("not num1:", not num1) 
print("not num2:", not num2)

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
num = 5
print(5**2)

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
num = int(input("wite a number : "))
if(num%2==0):
    print("Even")
else:
    print("Ödd")

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
num = int(input("wite a number : "))
ans=0
for i in range (1, num+1):
    ans=ans+i
print("The sum of the first",num,"natural numbers is : ",ans)

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
year = int(input("wite a year : "))
if(year%400==0):
    print("Leap Year")
elif(year%4==0 and year%100!=0):
    print("Leap year")
else:
    print("Not Leap Year")

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
string = input("wite a word : ")
ans=""
for i in range (len(string)-1, -1, -1):
    ans = ans+string[i]
print("Reverse of", string, "is",ans)

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
string = input("wite a word : ")
ans=""
for i in range (len(string)-1, -1, -1):
    ans = ans+string[i]
if(string==ans):
    print("Palindrome")
else:
    print("Not Palindrome")

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
num = list(map(int, input("Give a list of numbers : ").split()))
for i in range (0, len(num)):
    for j in range (i, len(num)):
        if(num[i]>num[j]):
            num[i]=num[i]+num[j]
            num[j]=num[i]-num[j]
            num[i]=num[i]-num[j]

print(num)
